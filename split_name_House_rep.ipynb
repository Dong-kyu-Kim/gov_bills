# %%
import pandas as pd
import os

# %%
csv_path = os.path.join("csv_files", "House_rep.csv")
df = pd.read_csv(csv_path, encoding = 'utf8')
df
# Out:
#                        Name Term Type       Party       Start Date  \
# 0        Robert B. Aderholt       rep  Republican       2023-01-03
# 1          Gus M. Bilirakis       rep  Republican       2023-01-03
# 2    Sanford D. Bishop, Jr.       rep    Democrat       2023-01-03
# 3           Earl Blumenauer       rep    Democrat       2023-01-03
# 4             Vern Buchanan       rep  Republican       2023-01-03
# ..                      ...       ...         ...              ...
# 430              Greg Lopez       rep  Republican       2024-07-08
# 431         LaMonica McIver       rep    Democrat       2024-09-18
# 432      Bill Pascrell, Jr.       rep    Democrat  January 3, 1997
# 433      Sheila Jackson Lee       rep    Democrat  January 3, 1995
# 434          Mike Gallagher       rep  Republican  January 3, 2017
#
#             End Date       State       District  \
# 0         2025-01-03          AL              4
# 1         2025-01-03          FL             12
# ...

# %%
df['Last Name'] = df['Name'].apply(lambda x: x.split()[-1])
df
# Out:
#                        Name Term Type       Party       Start Date  \
# 0        Robert B. Aderholt       rep  Republican       2023-01-03
# 1          Gus M. Bilirakis       rep  Republican       2023-01-03
# 2    Sanford D. Bishop, Jr.       rep    Democrat       2023-01-03
# 3           Earl Blumenauer       rep    Democrat       2023-01-03
# 4             Vern Buchanan       rep  Republican       2023-01-03
# ..                      ...       ...         ...              ...
# 430              Greg Lopez       rep  Republican       2024-07-08
# 431         LaMonica McIver       rep    Democrat       2024-09-18
# 432      Bill Pascrell, Jr.       rep    Democrat  January 3, 1997
# 433      Sheila Jackson Lee       rep    Democrat  January 3, 1995
# 434          Mike Gallagher       rep  Republican  January 3, 2017
#
#             End Date       State       District  \
# 0         2025-01-03          AL              4
# 1         2025-01-03          FL             12
# ...

# %%
output_csv_path = os.path.join("csv_files", "House_rep_modified.csv")
df.to_csv(output_csv_path, encoding='utf8', index=False)
